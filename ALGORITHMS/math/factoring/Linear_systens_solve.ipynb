# %%
import numpy as np
import time

# %%
# Global
start_time = time.time()

# %%
def debuger():
  print("iiiii")

# %%
def startTimer():
  start_time = time.time()

def getTimer():
  print("--- %s seconds ---" % (time.time() - start_time))

# %%
# Input example
# 3
# 3
# 2 -1 0 -1 2 -1 0 -1 2
def inputMatrix():
  r = int(input("Enter number of ROWS"))
  c = int(input("Enter number of COLUMNUS"))

  print("Enter matrix in single line separetad by spaces: ")
  try:
    entries = list(map(int, input().split()))
  except():
    
  matrix = np.array(entries).reshape(r, c)

  return matrix

# %%
def main():
  a = inputMatrix()
  print(a)
  
if __name__ == "__main__":
  main()
# Out:
# Enter number of ROWS0
# Enter number of COLUMNUS0
# Enter matrix in single line separetad by spaces:
# 998 8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-c7e3be0485bc> in <module>()
#       4
#       5 if __name__ == "__main__":
# ----> 6   main()
#
# <ipython-input-19-c7e3be0485bc> in main()
#       1 def main():
# ----> 2   a = inputMatrix()
#       3   print(a)
#       4
#       5 if __name__ == "__main__":
#
# <ipython-input-12-9f31136d8bfa> in inputMatrix()
#       6   entries = list(map(int, input().split()))
#       7
# ----> 8   matrix = np.array(entries).reshape(r, c)
#       9
#      10   return matrix
#
# ValueError: cannot reshape array of size 2 into shape (0,0)

# %%
print(os.interEqs([1,2],1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-db7ca4a6986b> in <module>()
# ----> 1 print(os.interEqs([1,2],1))
#
# AttributeError: module 'os' has no attribute 'interEqs'
